16:00', '2025-05-27T17:00', '2025-05-27T18:00', '2025-05-27T19:00', '2025-05-27T20:00', '2025-05-27T21:00', '2025-05-27T22:00', '2025-05-27T23:00', '2025-05-28T00:00', '2025-05-28T01:00', '2025-05-28T02:00', '2025-05-28T03:00', '2025-05-28T04:00', '2025-05-28T05:00', '2025-05-28T06:00', '2025-05-28T07:00', '2025-05-28T08:00', '2025-05-28T09:00', '2025-05-28T10:00', '2025-05-28T11:00', '2025-05-28T12:00', '2025-05-28T13:00', '2025-05-28T14:00', '2025-05-28T15:00', '2025-05-28T16:00', '2025-05-28T17:00', '2025-05-28T18:00', '2025-05-28T19:00', '2025-05-28T20:00', '2025-05-28T21:00', '2025-05-28T22:00', '2025-05-28T23:00', '2025-05-29T00:00', '2025-05-29T01:00', '2025-05-29T02:00', '2025-05-29T03:00', '2025-05-29T04:00', '2025-05-29T05:00', '2025-05-29T06:00', '2025-05-29T07:00', '2025-05-29T08:00', '2025-05-29T09:00', '2025-05-29T10:00', '2025-05-29T11:00', '2025-05-29T12:00', '2025-05-29T13:00', '2025-05-29T14:00', '2025-05-29T15:00', '2025-05-29T16:00', '2025-05-29T17:00', '2025-05-29T18:00', '2025-05-29T19:00', '2025-05-29T20:00', '2025-05-29T21:00', '2025-05-29T22:00', '2025-05-29T23:00'], 'windspeed_10m': [5.0, 2.4, 1.1, 2.9, 3.1, 2.6, 1.5, 0.8, 1.5, 3.7, 3.3, 2.3, 0.8, 1.8, 2.8, 8.4, 11.2, 11.8, 13.2, 13.5, 11.2, 9.2, 11.3, 9.7, 6.9, 3.7, 4.4, 3.2, 2.9, 2.7, 2.9, 2.5, 3.2, 2.6, 1.9, 1.8, 1.9, 1.8, 3.3, 8.8, 10.6, 10.6, 12.4, 12.0, 10.7, 10.2, 11.2, 9.6, 8.4, 5.8, 4.5, 4.8, 4.8, 3.6, 4.4, 3.0, 2.9, 2.6, 1.1, 2.3, 1.5, 1.6, 1.8, 4.1, 8 ...

# %%
import requests
from datetime import datetime

latitude = -18.0114
longitude = -70.2463

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}&hourly=windspeed_10m,winddirection_10m&timezone=America/Lima"
)

response = requests.get(url)

if response.status_code == 200:
    data = response.json()

    times = data['hourly']['time']
    wind_speeds = data['hourly']['windspeed_10m']
    wind_dirs = data['hourly']['winddirection_10m']

    print(f"Pronóstico horario de viento para Tacna, Perú:\n")
    for t, speed, direction in zip(times, wind_speeds, wind_dirs):
        # Convertir el tiempo de formato ISO a legible
        time_obj = datetime.fromisoformat(t)
        time_str = time_obj.strftime("%Y-%m-%d %H:%M")

        print(f"Hora: {time_str} | Velocidad del viento: {speed} km/h | Dirección del viento: {direction}°")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Pronóstico horario de viento para Tacna, Perú:
#
# Hora: 2025-05-23 00:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 196°
# Hora: 2025-05-23 01:00 | Velocidad del viento: 1.5 km/h | Dirección del viento: 104°
# Hora: 2025-05-23 02:00 | Velocidad del viento: 0.8 km/h | Dirección del viento: 27°
# Hora: 2025-05-23 03:00 | Velocidad del viento: 1.5 km/h | Dirección del viento: 135°
# Hora: 2025-05-23 04:00 | Velocidad del viento: 3.7 km/h | Dirección del viento: 209°
# Hora: 2025-05-23 05:00 | Velocidad del viento: 3.3 km/h | Dirección del viento: 221°
# Hora: 2025-05-23 06:00 | Velocidad del viento: 2.3 km/h | Dirección del viento: 219°
# Hora: 2025-05-23 07:00 | Velocidad del viento: 0.8 km/h | Dirección del viento: 27°
# Hora: 2025-05-23 08:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 233°
# Hora: 2025-05-23 09:00 | Velocidad del viento: 2.8 km/h | Dirección del viento: 230°
# Hora: 2025-05-23 10:00 | Velocidad del viento: 8.4 km/h | Dirección del viento: 227°
# Hora: 2025-05-23 11:00 | Velocidad del viento: 11.2 km/h | Dirección del viento: 220°
# Hora: 2025-05-23 12:00 | Velocidad del viento: 11.8 km/h | Dirección del viento: 220°
# Hora: 2025-05-23 13:00 | Velocidad del viento: 13.2 km/h | Dirección del viento: 215°
# Hora: 2025-05-23 14:00 | Velocidad del viento: 13.5 km/h | Dirección del viento: 214°
# Hora: 2025-05-23 15:00 | Velocidad del viento: 11.2 km/h | Dirección del viento: 213°
# Hora: 2025-05-23 16:00 | Velocidad del viento: 9.2 km/h | Dirección del viento: 211°
# Hora: 2025-05-23 17:00 | Velocidad del viento: 11.3 km/h | Dirección del viento: 211°
# Hora: 2025-05-23 18:00 | Velocidad del viento: 9.7 km/h | Dirección del viento: 207°
# Hora: 2025-05-23 19:00 | Velocidad del viento: 6.9 km/h | Dirección del viento: 208°
# Hora: 2025-05-23 20:00 | Velocidad del viento: 3.7 km/h | Dirección del viento: 191°
# Hora: 2025-05-23 21:00 | Velocidad del viento: 4.4 km/h | Dirección del viento: 189°
# Hora: 2025-05-23 22:00 | Velocidad del viento: 3.2 km/h | Dirección del viento: 153°
# Hora: 2025-05-23 23:00 | Velocidad del viento: 2.9 km/h | Dirección del viento: 120°
# Hora: 2025-05-24 00:00 | Velocidad del viento: 2.7 km/h | Dirección del viento: 157°
# Hora: 2025-05-24 01:00 | Velocidad del viento: 2.9 km/h | Dirección del viento: 173°
# Hora: 2025-05-24 02:00 | Velocidad del viento: 2.5 km/h | Dirección del viento: 172°
# Hora: 2025-05-24 03:00 | Velocidad del viento: 3.2 km/h | Dirección del viento: 180°
# Hora: 2025-05-24 04:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 146°
# Hora: 2025-05-24 05:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 158°
# Hora: 2025-05-24 06:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 143°
# Hora: 2025-05-24 07:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 112°
# Hora: 2025-05-24 08:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 127°
# Hora: 2025-05-24 09:00 | Velocidad del viento: 3.3 km/h | Dirección del viento: 186°
# Hora: 2025-05-24 10:00 | Velocidad del viento: 8.8 km/h | Dirección del viento: 215°
# Hora: 2025-05-24 11:00 | Velocidad del viento: 10.6 km/h | Dirección del viento: 215°
# Hora: 2025-05-24 12:00 | Velocidad del viento: 10.6 km/h | Dirección del viento: 215°
# Hora: 2025-05-24 13:00 | Velocidad del viento: 12.4 km/h | Dirección del viento: 216°
# Hora: 2025-05-24 14:00 | Velocidad del viento: 12.0 km/h | Dirección del viento: 213°
# Hora: 2025-05-24 15:00 | Velocidad del viento: 10.7 km/h | Dirección del viento: 213°
# Hora: 2025-05-24 16:00 | Velocidad del viento: 10.2 km/h | Dirección del viento: 212°
# Hora: 2025-05-24 17:00 | Velocidad del viento: 11.2 km/h | Dirección del viento: 213°
# Hora: 2025-05-24 18:00 | Velocidad del viento: 9.6 km/h | Dirección del viento: 214°
# Hora: 2025-05-24 19:00 | Velocidad del viento: 8.4 km/h | Dirección del viento: 205°
# Hora: 2025-05-24 20:00 | Velocidad del viento: 5.8 km/h | Dirección del viento: 210°
# Hora: 2025-05-24 21:00 | Velocidad del viento: 4.5 km/h | Dirección del viento: 194°
# Hora: 2025-05-24 22:00 | Velocidad del viento: 4.8 km/h | Dirección del viento: 207°
# Hora: 2025-05-24 23:00 | Velocidad del viento: 4.8 km/h | Dirección del viento: 207°
# Hora: 2025-05-25 00:00 | Velocidad del viento: 3.6 km/h | Dirección del viento: 180°
# Hora: 2025-05-25 01:00 | Velocidad del viento: 4.4 km/h | Dirección del viento: 145°
# Hora: 2025-05-25 02:00 | Velocidad del viento: 3.0 km/h | Dirección del viento: 166°
# Hora: 2025-05-25 03:00 | Velocidad del viento: 2.9 km/h | Dirección del viento: 187°
# Hora: 2025-05-25 04:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 164°
# Hora: 2025-05-25 05:00 | Velocidad del viento: 1.1 km/h | Dirección del viento: 162°
# Hora: 2025-05-25 06:00 | Velocidad del viento: 2.3 km/h | Dirección del viento: 162°
# Hora: 2025-05-25 07:00 | Velocidad del viento: 1.5 km/h | Dirección del viento: 135°
# Hora: 2025-05-25 08:00 | Velocidad del viento: 1.6 km/h | Dirección del viento: 153°
# Hora: 2025-05-25 09:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 180°
# Hora: 2025-05-25 10:00 | Velocidad del viento: 4.1 km/h | Dirección del viento: 218°
# Hora: 2025-05-25 11:00 | Velocidad del viento: 8.1 km/h | Dirección del viento: 212°
# Hora: 2025-05-25 12:00 | Velocidad del viento: 10.0 km/h | Dirección del viento: 210°
# Hora: 2025-05-25 13:00 | Velocidad del viento: 13.0 km/h | Dirección del viento: 208°
# Hora: 2025-05-25 14:00 | Velocidad del viento: 13.5 km/h | Dirección del viento: 209°
# Hora: 2025-05-25 15:00 | Velocidad del viento: 11.3 km/h | Dirección del viento: 207°
# Hora: 2025-05-25 16:00 | Velocidad del viento: 12.9 km/h | Dirección del viento: 216°
# Hora: 2025-05-25 17:00 | Velocidad del viento: 11.7 km/h | Dirección del viento: 214°
# Hora: 2025-05-25 18:00 | Velocidad del viento: 10.0 km/h | Dirección del viento: 210°
# Hora: 2025-05-25 19:00 | Velocidad del viento: 8.4 km/h | Dirección del viento: 211°
# Hora: 2025-05-25 20:00 | Velocidad del viento: 6.5 km/h | Dirección del viento: 177°
# Hora: 2025-05-25 21:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 196°
# Hora: 2025-05-25 22:00 | Velocidad del viento: 0.4 km/h | Dirección del viento: 180°
# Hora: 2025-05-25 23:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 143°
# Hora: 2025-05-26 00:00 | Velocidad del viento: 2.7 km/h | Dirección del viento: 113°
# Hora: 2025-05-26 01:00 | Velocidad del viento: 2.5 km/h | Dirección del viento: 172°
# Hora: 2025-05-26 02:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 191°
# Hora: 2025-05-26 03:00 | Velocidad del viento: 1.6 km/h | Dirección del viento: 243°
# Hora: 2025-05-26 04:00 | Velocidad del viento: 2.0 km/h | Dirección del viento: 225°
# Hora: 2025-05-26 05:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 214°
# Hora: 2025-05-26 06:00 | Velocidad del viento: 0.5 km/h | Dirección del viento: 45°
# Hora: 2025-05-26 07:00 | Velocidad del viento: 0.4 km/h | Dirección del viento: 270°
# Hora: 2025-05-26 08:00 | Velocidad del viento: 2.3 km/h | Dirección del viento: 231°
# Hora: 2025-05-26 09:00 | Velocidad del viento: 5.4 km/h | Dirección del viento: 228°
# Hora: 2025-05-26 10:00 | Velocidad del viento: 7.6 km/h | Dirección del viento: 225°
# Hora: 2025-05-26 11:00 | Velocidad del viento: 8.9 km/h | Dirección del viento: 220°
# Hora: 2025-05-26 12:00 | Velocidad del viento: 9.6 km/h | Dirección del viento: 214°
# Hora: 2025-05-26 13:00 | Velocidad del viento: 10.3 km/h | Dirección del viento: 209°
# Hora: 2025-05-26 14:00 | Velocidad del viento: 10.9 km/h | Dirección del viento: 207°
# Hora: 2025-05-26 15:00 | Velocidad del viento: 11.3 km/h | Dirección del viento: 207°
# Hora: 2025-05-26 16:00 | Velocidad del viento: 11.3 km/h | Dirección del viento: 207°
# Hora: 2025-05-26 17:00 | Velocidad del viento: 10.3 km/h | Dirección del viento: 209°
# Hora: 2025-05-26 18:00 | Velocidad del viento: 9.1 km/h | Dirección del viento: 214°
# Hora: 2025-05-26 19:00 | Velocidad del viento: 7.7 km/h | Dirección del viento: 217°
# Hora: 2025-05-26 20:00 | Velocidad del viento: 6.5 km/h | Dirección del viento: 214°
# Hora: 2025-05-26 21:00 | Velocidad del viento: 5.6 km/h | Dirección del viento: 207°
# Hora: 2025-05-26 22:00 | Velocidad del viento: 4.5 km/h | Dirección del viento: 194°
# Hora: 2025-05-26 23:00 | Velocidad del viento: 2.9 km/h | Dirección del viento: 173°
# Hora: 2025-05-27 00:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 127°
# Hora: 2025-05-27 01:00 | Velocidad del viento: 2.2 km/h | Dirección del viento: 90°
# Hora: 2025-05-27 02:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 68°
# Hora: 2025-05-27 03:00 | Velocidad del viento: 1.3 km/h | Dirección del viento: 56°
# Hora: 2025-05-27 04:00 | Velocidad del viento: 0.5 km/h | Dirección del viento: 45°
# Hora: 2025-05-27 05:00 | Velocidad del viento: 0.8 km/h | Dirección del viento: 153°
# Hora: 2025-05-27 06:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 164°
# Hora: 2025-05-27 07:00 | Velocidad del viento: 3.6 km/h | Dirección del viento: 174°
# Hora: 2025-05-27 08:00 | Velocidad del viento: 3.3 km/h | Dirección del viento: 193°
# Hora: 2025-05-27 09:00 | Velocidad del viento: 3.6 km/h | Dirección del viento: 225°
# Hora: 2025-05-27 10:00 | Velocidad del viento: 4.7 km/h | Dirección del viento: 238°
# Hora: 2025-05-27 11:00 | Velocidad del viento: 6.6 km/h | Dirección del viento: 225°
# Hora: 2025-05-27 12:00 | Velocidad del viento: 9.6 km/h | Dirección del viento: 214°
# Hora: 2025-05-27 13:00 | Velocidad del viento: 11.6 km/h | Dirección del viento: 210°
# Hora: 2025-05-27 14:00 | Velocidad del viento: 11.8 km/h | Dirección del viento: 211°
# Hora: 2025-05-27 15:00 | Velocidad del viento: 10.9 km/h | Dirección del viento: 214°
# Hora: 2025-05-27 16:00 | Velocidad del viento: 10.0 km/h | Dirección del viento: 218°
# Hora: 2025-05-27 17:00 | Velocidad del viento: 9.6 km/h | Dirección del viento: 214°
# Hora: 2025-05-27 18:00 | Velocidad del viento: 9.2 km/h | Dirección del viento: 211°
# Hora: 2025-05-27 19:00 | Velocidad del viento: 8.4 km/h | Dirección del viento: 205°
# Hora: 2025-05-27 20:00 | Velocidad del viento: 7.0 km/h | Dirección del viento: 201°
# Hora: 2025-05-27 21:00 | Velocidad del viento: 5.2 km/h | Dirección del viento: 196°
# Hora: 2025-05-27 22:00 | Velocidad del viento: 3.7 km/h | Dirección del viento: 191°
# Hora: 2025-05-27 23:00 | Velocidad del viento: 2.5 km/h | Dirección del viento: 180°
# Hora: 2025-05-28 00:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 158°
# Hora: 2025-05-28 01:00 | Velocidad del viento: 1.5 km/h | Dirección del viento: 135°
# Hora: 2025-05-28 02:00 | Velocidad del viento: 2.2 km/h | Dirección del viento: 180°
# Hora: 2025-05-28 03:00 | Velocidad del viento: 2.6 km/h | Dirección del viento: 196°
# Hora: 2025-05-28 04:00 | Velocidad del viento: 3.1 km/h | Dirección del viento: 201°
# Hora: 2025-05-28 05:00 | Velocidad del viento: 2.2 km/h | Dirección del viento: 189°
# Hora: 2025-05-28 06:00 | Velocidad del viento: 1.1 km/h | Dirección del viento: 162°
# Hora: 2025-05-28 07:00 | Velocidad del viento: 1.0 km/h | Dirección del viento: 135°
# Hora: 2025-05-28 08:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 202°
# Hora: 2025-05-28 09:00 | Velocidad del viento: 4.3 km/h | Dirección del viento: 222°
# Hora: 2025-05-28 10:00 | Velocidad del viento: 6.9 km/h | Dirección del viento: 223°
# Hora: 2025-05-28 11:00 | Velocidad del viento: 8.9 km/h | Dirección del viento: 220°
# Hora: 2025-05-28 12:00 | Velocidad del viento: 11.1 km/h | Dirección del viento: 216°
# Hora: 2025-05-28 13:00 | Velocidad del viento: 12.2 km/h | Dirección del viento: 214°
# Hora: 2025-05-28 14:00 | Velocidad del viento: 11.8 km/h | Dirección del viento: 211°
# Hora: 2025-05-28 15:00 | Velocidad del viento: 10.9 km/h | Dirección del viento: 207°
# Hora: 2025-05-28 16:00 | Velocidad del viento: 10.0 km/h | Dirección del viento: 206°
# Hora: 2025-05-28 17:00 | Velocidad del viento: 9.5 km/h | Dirección del viento: 209°
# Hora: 2025-05-28 18:00 | Velocidad del viento: 9.0 km/h | Dirección del viento: 217°
# Hora: 2025-05-28 19:00 | Velocidad del viento: 8.7 km/h | Dirección del viento: 222°
# Hora: 2025-05-28 20:00 | Velocidad del viento: 7.9 km/h | Dirección del viento: 223°
# Hora: 2025-05-28 21:00 | Velocidad del viento: 6.4 km/h | Dirección del viento: 223°
# Hora: 2025-05-28 22:00 | Velocidad del viento: 4.9 km/h | Dirección del viento: 216°
# Hora: 2025-05-28 23:00 | Velocidad del viento: 3.0 km/h | Dirección del viento: 194°
# Hora: 2025-05-29 00:00 | Velocidad del viento: 2.5 km/h | Dirección del viento: 135°
# Hora: 2025-05-29 01:00 | Velocidad del viento: 3.4 km/h | Dirección del viento: 108°
# Hora: 2025-05-29 02:00 | Velocidad del viento: 3.1 km/h | Dirección del viento: 111°
# Hora: 2025-05-29 03:00 | Velocidad del viento: 1.8 km/h | Dirección del viento: 143°
# Hora: 2025-05-29 04:00 | Velocidad del viento: 1.4 km/h | Dirección del viento: 180°
# Hora: 2025-05-29 05:00 | Velocidad del viento: 1.1 km/h | Dirección del viento: 198°
# Hora: 2025-05-29 06:00 | Velocidad del viento: 0.8 km/h | Dirección del viento: 207°
# Hora: 2025-05-29 07:00 | Velocidad del viento: 1.0 km/h | Dirección del viento: 225°
# Hora: 2025-05-29 08:00 | Velocidad del viento: 2.5 km/h | Dirección del viento: 225°
# Hora: 2025-05-29 09:00 | Velocidad del viento: 4.3 km/h | Dirección del viento: 228°
# Hora: 2025-05-29 10:00 | Velocidad del viento: 6.6 km/h | Dirección del viento: 225°
# Hora: 2025-05-29 11:00 | Velocidad del viento: 8.9 km/h | Dirección del viento: 220°
# Hora: 2025-05-29 12:00 | Velocidad del viento: 11.1 km/h | Dirección del viento: 216°
# Hora: 2025-05-29 13:00 | Velocidad del viento: 12.3 km/h | Dirección del viento: 212°
# Hora: 2025-05-29 14:00 | Velocidad del viento: 11.8 km/h | Dirección del viento: 207°
# Hora: 2025-05-29 15:00 | Velocidad del viento: 10.5 km/h | Dirección del viento: 202°
# Hora: 2025-05-29 16:00 | Velocidad del viento: 9.2 km/h | Dirección del viento: 201°
# Hora: 2025-05-29 17:00 | Velocidad del viento: 8.5 km/h | Dirección del viento: 208°
# Hora: 2025-05-29 18:00 | Velocidad del viento: 8.2 km/h | Dirección del viento: 218°
# Hora: 2025-05-29 19:00 | Velocidad del viento: 7.6 km/h | Dirección del viento: 225°
# Hora: 2025-05-29 20:00 | Velocidad del viento: 5.9 km/h | Dirección del viento: 223°
# Hora: 2025-05-29 21:00 | Velocidad del viento: 3.2 km/h | Dirección del viento: 207°
# Hora: 2025-05-29 22:00 | Velocidad del viento: 1.9 km/h | Dirección del viento: 158°
# Hora: 2025-05-29 23:00 | Velocidad del viento: 2.1 km/h | Dirección del viento: 121°

# %%
import requests
from datetime import datetime
import pytz

latitude = -18.0114
longitude = -70.2463

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}&hourly=windspeed_10m,winddirection_10m&timezone=America/Lima"
)

response = requests.get(url)

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

if response.status_code == 200:
    data = response.json()

    times_local = data['hourly']['time']
    wind_speeds = data['hourly']['windspeed_10m']
    wind_dirs = data['hourly']['winddirection_10m']

    # Para convertir tiempo local a UTC
    local_tz = pytz.timezone('America/Lima')

    print(f"{'Hora Local (America/Lima)':20} | {'Hora UTC':20} | {'Velocidad (km/h)':15} | {'Dirección (°)':15} | {'Orientación'}")
    print("-"*95)

    for t, speed, direction in zip(times_local, wind_speeds, wind_dirs):
        # Parsear tiempo local en formato ISO
        local_dt = datetime.fromisoformat(t)
        local_dt = local_tz.localize(local_dt)

        # Convertir a UTC
        utc_dt = local_dt.astimezone(pytz.utc)

        # Obtener orientación cardinal
        cardinal = degrees_to_cardinal(direction)

        print(f"{local_dt.strftime('%Y-%m-%d %H:%M'):20} | {utc_dt.strftime('%Y-%m-%d %H:%M'):20} | {speed:<15} | {direction:<15} | {cardinal}")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Hora Local (America/Lima) | Hora UTC             | Velocidad (km/h) | Dirección (°)   | Orientación
# -----------------------------------------------------------------------------------------------
# 2025-05-23 00:00     | 2025-05-23 05:00     | 2.6             | 196             | SSW
# 2025-05-23 01:00     | 2025-05-23 06:00     | 1.5             | 104             | ESE
# 2025-05-23 02:00     | 2025-05-23 07:00     | 0.8             | 27              | NNE
# 2025-05-23 03:00     | 2025-05-23 08:00     | 1.5             | 135             | SE
# 2025-05-23 04:00     | 2025-05-23 09:00     | 3.7             | 209             | SSW
# 2025-05-23 05:00     | 2025-05-23 10:00     | 3.3             | 221             | SW
# 2025-05-23 06:00     | 2025-05-23 11:00     | 2.3             | 219             | SW
# 2025-05-23 07:00     | 2025-05-23 12:00     | 0.8             | 27              | NNE
# 2025-05-23 08:00     | 2025-05-23 13:00     | 1.8             | 233             | SW
# 2025-05-23 09:00     | 2025-05-23 14:00     | 2.8             | 230             | SW
# 2025-05-23 10:00     | 2025-05-23 15:00     | 8.4             | 227             | SW
# 2025-05-23 11:00     | 2025-05-23 16:00     | 11.2            | 220             | SW
# 2025-05-23 12:00     | 2025-05-23 17:00     | 11.8            | 220             | SW
# 2025-05-23 13:00     | 2025-05-23 18:00     | 13.2            | 215             | SW
# 2025-05-23 14:00     | 2025-05-23 19:00     | 13.5            | 214             | SW
# 2025-05-23 15:00     | 2025-05-23 20:00     | 11.2            | 213             | SSW
# 2025-05-23 16:00     | 2025-05-23 21:00     | 9.2             | 211             | SSW
# 2025-05-23 17:00     | 2025-05-23 22:00     | 11.3            | 211             | SSW
# 2025-05-23 18:00     | 2025-05-23 23:00     | 9.7             | 207             | SSW
# 2025-05-23 19:00     | 2025-05-24 00:00     | 6.9             | 208             | SSW
# 2025-05-23 20:00     | 2025-05-24 01:00     | 3.7             | 191             | S
# 2025-05-23 21:00     | 2025-05-24 02:00     | 4.4             | 189             | S
# 2025-05-23 22:00     | 2025-05-24 03:00     | 3.2             | 153             | SSE
# 2025-05-23 23:00     | 2025-05-24 04:00     | 2.9             | 120             | ESE
# 2025-05-24 00:00     | 2025-05-24 05:00     | 2.7             | 157             | SSE
# 2025-05-24 01:00     | 2025-05-24 06:00     | 2.9             | 173             | S
# 2025-05-24 02:00     | 2025-05-24 07:00     | 2.5             | 172             | S
# 2025-05-24 03:00     | 2025-05-24 08:00     | 3.2             | 180             | S
# 2025-05-24 04:00     | 2025-05-24 09:00     | 2.6             | 146             | SE
# 2025-05-28 22:00     | 2025-05-29 03:00     | 4.9             | 216             | SW
# 2025-05-28 23:00     | 2025-05-29 04:00     | 3.0             | 194             | SSW
# 2025-05-29 00:00     | 2025-05-29 05:00     | 2.5             | 135             | SE
# 2025-05-29 01:00     | 2025-05-29 06:00     | 3.4             | 108             | ESE
# 2025-05-29 02:00     | 2025-05-29 07:00     | 3.1             | 111             | ESE
# 2025-05-29 03:00     | 2025-05-29 08:00     | 1.8             | 143             | SE
# 2025-05-29 04:00     | 2025-05-29 09:00     | 1.4             | 180             | S
# 2025-05-29 05:00     | 2025-05-29 10:00     | 1.1             | 198             | SSW
# 2025-05-29 06:00     | 2025-05-29 11:00     | 0.8             | 207             | SSW
# 2025-05-29 07:00     | 2025-05-29 12:00     | 1.0             | 225             | SW
# 2025-05-29 08:00     | 2025-05-29 13:00     | 2.5             | 225             | SW
# 2025-05-29 09:00     | 2025-05-29 14:00     | 4.3             | 228             | SW
# 2025-05-29 10:00     | 2025-05-29 15:00     | 6.6             | 225             | SW
# 2025-05-29 11:00     | 2025-05-29 16:00     | 8.9             | 220             | SW
# 2025-05-29 12:00     | 2025-05-29 17:00     | 11.1            | 216             | SW
# 2025-05-29 13:00     | 2025-05-29 18:00     | 12.3            | 212             | SSW
# 2025-05-29 14:00     | 2025-05-29 19:00     | 11.8            | 207             | SSW
# 2025-05-29 15:00     | 2025-05-29 20:00     | 10.5            | 202             | SSW
# 2025-05-29 16:00     | 2025-05-29 21:00     | 9.2             | 201             | SSW
# 2025-05-29 17:00     | 2025-05-29 22:00     | 8.5             | 208             | SSW
# 2025-05-29 18:00     | 2025-05-29 23:00     | 8.2             | 218             | SW
# 2025-05-29 19:00     | 2025-05-30 00:00     | 7.6             | 225             | SW
# 2025-05-29 20:00     | 2025-05-30 01:00     | 5.9             | 223             | SW
# 2025-05-29 21:00     | 2025-05-30 02:00     | 3.2             | 207             | SSW
# 2025-05-29 22:00     | 2025-05-30 03:00     | 1.9             | 158             | SSE
# 2025-05-29 23:00     | 2025-05-30 04:00     | 2.1             | 121             | ESE

# %%
import requests
from datetime import datetime
import pytz
import csv

latitude = -18.0114
longitude = -70.2463

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}&hourly=windspeed_10m,winddirection_10m&timezone=America/Lima"
)

response = requests.get(url)

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

if response.status_code == 200:
    data = response.json()

    times_local = data['hourly']['time']
    wind_speeds = data['hourly']['windspeed_10m']
    wind_dirs = data['hourly']['winddirection_10m']

    local_tz = pytz.timezone('America/Lima')

    # Crear y escribir en CSV
    with open('viento_tacna.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Escribir encabezados
        writer.writerow(['Hora Local (America/Lima)', 'Hora UTC', 'Velocidad (km/h)', 'Dirección (°)', 'Orientación'])

        for t, speed, direction in zip(times_local, wind_speeds, wind_dirs):
            local_dt = datetime.fromisoformat(t)
            local_dt = local_tz.localize(local_dt)
            utc_dt = local_dt.astimezone(pytz.utc)
            cardinal = degrees_to_cardinal(direction)

            # Escribir fila en CSV
            writer.writerow([
                local_dt.strftime('%Y-%m-%d %H:%M'),
                utc_dt.strftime('%Y-%m-%d %H:%M'),
                speed,
                direction,
                cardinal
            ])

    print("Archivo 'viento_tacna.csv' creado con éxito.")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Archivo 'viento_tacna.csv' creado con éxito.

# %%
import requests
from datetime import datetime
import pytz

latitude = -18.0114
longitude = -70.2463

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}&hourly=windspeed_10m,winddirection_10m&timezone=America/Lima"
)

response = requests.get(url)

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

if response.status_code == 200:
    data = response.json()

    times_local = data['hourly']['time']
    wind_speeds_kmh = data['hourly']['windspeed_10m']
    wind_dirs = data['hourly']['winddirection_10m']

    # Para convertir tiempo local a UTC
    local_tz = pytz.timezone('America/Lima')

    print(f"{'Hora Local (America/Lima)':20} | {'Hora UTC':20} | {'Velocidad (m/s)':15} | {'Dirección (°)':15} | {'Orientación'}")
    print("-"*95)

    for t, speed_kmh, direction in zip(times_local, wind_speeds_kmh, wind_dirs):
        # Parsear tiempo local en formato ISO
        local_dt = datetime.fromisoformat(t)
        local_dt = local_tz.localize(local_dt)

        # Convertir a UTC
        utc_dt = local_dt.astimezone(pytz.utc)

        # Convertir velocidad de km/h a m/s
        speed_ms = speed_kmh / 3.6

        # Obtener orientación cardinal
        cardinal = degrees_to_cardinal(direction)

        print(f"{local_dt.strftime('%Y-%m-%d %H:%M'):20} | {utc_dt.strftime('%Y-%m-%d %H:%M'):20} | {speed_ms:<15.2f} | {direction:<15} | {cardinal}")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Hora Local (America/Lima) | Hora UTC             | Velocidad (m/s) | Dirección (°)   | Orientación
# -----------------------------------------------------------------------------------------------
# 2025-05-23 00:00     | 2025-05-23 05:00     | 0.72            | 196             | SSW
# 2025-05-23 01:00     | 2025-05-23 06:00     | 0.42            | 104             | ESE
# 2025-05-23 02:00     | 2025-05-23 07:00     | 0.22            | 27              | NNE
# 2025-05-23 03:00     | 2025-05-23 08:00     | 0.42            | 135             | SE
# 2025-05-23 04:00     | 2025-05-23 09:00     | 1.03            | 209             | SSW
# 2025-05-23 05:00     | 2025-05-23 10:00     | 0.92            | 221             | SW
# 2025-05-23 06:00     | 2025-05-23 11:00     | 0.64            | 219             | SW
# 2025-05-23 07:00     | 2025-05-23 12:00     | 0.22            | 27              | NNE
# 2025-05-23 08:00     | 2025-05-23 13:00     | 0.50            | 233             | SW
# 2025-05-23 09:00     | 2025-05-23 14:00     | 0.78            | 230             | SW
# 2025-05-23 10:00     | 2025-05-23 15:00     | 2.33            | 227             | SW
# 2025-05-23 11:00     | 2025-05-23 16:00     | 3.11            | 220             | SW
# 2025-05-23 12:00     | 2025-05-23 17:00     | 3.28            | 220             | SW
# 2025-05-23 13:00     | 2025-05-23 18:00     | 3.67            | 215             | SW
# 2025-05-23 14:00     | 2025-05-23 19:00     | 3.75            | 214             | SW
# 2025-05-23 15:00     | 2025-05-23 20:00     | 3.11            | 213             | SSW
# 2025-05-23 16:00     | 2025-05-23 21:00     | 2.56            | 211             | SSW
# 2025-05-23 17:00     | 2025-05-23 22:00     | 3.14            | 211             | SSW
# 2025-05-23 18:00     | 2025-05-23 23:00     | 2.69            | 207             | SSW
# 2025-05-23 19:00     | 2025-05-24 00:00     | 1.92            | 208             | SSW
# 2025-05-23 20:00     | 2025-05-24 01:00     | 1.03            | 191             | S
# 2025-05-28 14:00     | 2025-05-28 19:00     | 3.28            | 211             | SSW
# 2025-05-28 15:00     | 2025-05-28 20:00     | 3.03            | 207             | SSW
# 2025-05-28 16:00     | 2025-05-28 21:00     | 2.78            | 206             | SSW
# 2025-05-28 17:00     | 2025-05-28 22:00     | 2.64            | 209             | SSW
# 2025-05-28 18:00     | 2025-05-28 23:00     | 2.50            | 217             | SW
# 2025-05-28 19:00     | 2025-05-29 00:00     | 2.42            | 222             | SW
# 2025-05-28 20:00     | 2025-05-29 01:00     | 2.19            | 223             | SW
# 2025-05-28 21:00     | 2025-05-29 02:00     | 1.78            | 223             | SW
# 2025-05-28 22:00     | 2025-05-29 03:00     | 1.36            | 216             | SW
# 2025-05-28 23:00     | 2025-05-29 04:00     | 0.83            | 194             | SSW
# 2025-05-29 00:00     | 2025-05-29 05:00     | 0.69            | 135             | SE
# 2025-05-29 01:00     | 2025-05-29 06:00     | 0.94            | 108             | ESE
# 2025-05-29 02:00     | 2025-05-29 07:00     | 0.86            | 111             | ESE
# 2025-05-29 03:00     | 2025-05-29 08:00     | 0.50            | 143             | SE
# 2025-05-29 04:00     | 2025-05-29 09:00     | 0.39            | 180             | S
# 2025-05-29 05:00     | 2025-05-29 10:00     | 0.31            | 198             | SSW
# 2025-05-29 06:00     | 2025-05-29 11:00     | 0.22            | 207             | SSW
# 2025-05-29 07:00     | 2025-05-29 12:00     | 0.28            | 225             | SW
# 2025-05-29 08:00     | 2025-05-29 13:00     | 0.69            | 225             | SW
# 2025-05-29 09:00     | 2025-05-29 14:00     | 1.19            | 228             | SW
# 2025-05-29 10:00     | 2025-05-29 15:00     | 1.83            | 225             | SW
# 2025-05-29 11:00     | 2025-05-29 16:00     | 2.47            | 220             | SW
# 2025-05-29 12:00     | 2025-05-29 17:00     | 3.08            | 216             | SW
# 2025-05-29 13:00     | 2025-05-29 18:00     | 3.42            | 212             | SSW
# 2025-05-29 14:00     | 2025-05-29 19:00     | 3.28            | 207             | SSW
# 2025-05-29 15:00     | 2025-05-29 20:00     | 2.92            | 202             | SSW
# 2025-05-29 16:00     | 2025-05-29 21:00     | 2.56            | 201             | SSW
# 2025-05-29 17:00     | 2025-05-29 22:00     | 2.36            | 208             | SSW
# 2025-05-29 18:00     | 2025-05-29 23:00     | 2.28            | 218             | SW
# 2025-05-29 19:00     | 2025-05-30 00:00     | 2.11            | 225             | SW
# 2025-05-29 20:00     | 2025-05-30 01:00     | 1.64            | 223             | SW
# 2025-05-29 21:00     | 2025-05-30 02:00     | 0.89            | 207             | SSW
# 2025-05-29 22:00     | 2025-05-30 03:00     | 0.53            | 158             | SSE
# 2025-05-29 23:00     | 2025-05-30 04:00     | 0.58            | 121             | ESE

# %%
import requests
from datetime import datetime
import pytz
import csv

latitude = -18.0114
longitude = -70.2463

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}&longitude={longitude}&hourly=windspeed_10m,winddirection_10m&timezone=America/Lima"
)

response = requests.get(url)

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

if response.status_code == 200:
    data = response.json()

    times_local = data['hourly']['time']
    wind_speeds_kmh = data['hourly']['windspeed_10m']
    wind_dirs = data['hourly']['winddirection_10m']

    local_tz = pytz.timezone('America/Lima')

    # Crear archivo CSV y escribir encabezado
    with open('viento_tacna_m_s.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Hora Local (America/Lima)', 'Hora UTC', 'Velocidad (m/s)', 'Dirección (°)', 'Orientación'])

        for t, speed_kmh, direction in zip(times_local, wind_speeds_kmh, wind_dirs):
            local_dt = datetime.fromisoformat(t)
            local_dt = local_tz.localize(local_dt)
            utc_dt = local_dt.astimezone(pytz.utc)

            speed_ms = speed_kmh / 3.6
            cardinal = degrees_to_cardinal(direction)

            writer.writerow([
                local_dt.strftime('%Y-%m-%d %H:%M'),
                utc_dt.strftime('%Y-%m-%d %H:%M'),
                f"{speed_ms:.2f}",
                f"{direction:.1f}",
                cardinal
            ])
    print("Archivo 'viento_tacna_m_s.csv' creado con éxito.")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Archivo 'viento_tacna_m_s.csv' creado con éxito.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Cargar datos desde CSV
df = pd.read_csv('viento_tacna_m_s.csv')

# Convertir columna 'Hora Local (America/Lima)' a datetime
df['Hora Local (America/Lima)'] = pd.to_datetime(df['Hora Local (America/Lima)'])

# Extraer la fecha (sin hora) para agrupar por día
df['Fecha'] = df['Hora Local (America/Lima)'].dt.date

# Agrupar por día y calcular velocidad media diaria del viento
daily_wind = df.groupby('Fecha')['Velocidad (m/s)'].mean()

# Encontrar día con mayor y menor velocidad media
dia_mayor_viento = daily_wind.idxmax()
mayor_velocidad = daily_wind.max()

dia_menor_viento = daily_wind.idxmin()
menor_velocidad = daily_wind.min()

print(f"Día con mayor viento promedio: {dia_mayor_viento} con {mayor_velocidad:.2f} m/s")
print(f"Día con menor viento promedio: {dia_menor_viento} con {menor_velocidad:.2f} m/s")

# Calcular tendencia lineal (regresión simple)
# Convertimos las fechas a números para la regresión (días desde el primero)
x = np.arange(len(daily_wind))
y = daily_wind.values

# Coeficiente angular (pendiente) de la regresión lineal
coef = np.polyfit(x, y, 1)[0]

if coef > 0:
    print(f"Tendencia: Aumento de velocidad del viento en {coef:.4f} m/s por día.")
elif coef < 0:
    print(f"Tendencia: Disminución de velocidad del viento en {abs(coef):.4f} m/s por día.")
else:
    print("Tendencia: Velocidad del viento estable sin cambios significativos.")
# Out:
# Día con mayor viento promedio: 2025-05-24 con 1.72 m/s
# Día con menor viento promedio: 2025-05-29 con 1.50 m/s
# Tendencia: Disminución de velocidad del viento en 0.0226 m/s por día.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# Cargar datos desde CSV
df = pd.read_csv('viento_tacna_m_s.csv')

# Convertir columna 'Hora Local (America/Lima)' a datetime
df['Hora Local (America/Lima)'] = pd.to_datetime(df['Hora Local (America/Lima)'])

# Extraer la fecha (sin hora) para agrupar por día
df['Fecha'] = df['Hora Local (America/Lima)'].dt.date

# Agrupar por día y calcular velocidad media diaria del viento
daily_wind = df.groupby('Fecha')['Velocidad (m/s)'].mean()

# Encontrar día con mayor y menor velocidad media
dia_mayor_viento = daily_wind.idxmax()
mayor_velocidad = daily_wind.max()

dia_menor_viento = daily_wind.idxmin()
menor_velocidad = daily_wind.min()

print(f"Día con mayor viento promedio: {dia_mayor_viento} con {mayor_velocidad:.2f} m/s")
print(f"Día con menor viento promedio: {dia_menor_viento} con {menor_velocidad:.2f} m/s")

# Calcular tendencia lineal (regresión simple)
x = np.arange(len(daily_wind))
y = daily_wind.values

coef, intercept = np.polyfit(x, y, 1)

if coef > 0:
    print(f"Tendencia: Aumento de velocidad del viento en {coef:.4f} m/s por día.")
elif coef < 0:
    print(f"Tendencia: Disminución de velocidad del viento en {abs(coef):.4f} m/s por día.")
else:
    print("Tendencia: Velocidad del viento estable sin cambios significativos.")

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.scatter(daily_wind.index, y, color='blue', label='Velocidad media diaria (m/s)')
plt.plot(daily_wind.index, coef * x + intercept, color='red', label='Tendencia lineal')

plt.title('Velocidad media diaria del viento en Tacna')
plt.xlabel('Fecha')
plt.ylabel('Velocidad del viento (m/s)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Día con mayor viento promedio: 2025-05-24 con 1.72 m/s
# Día con menor viento promedio: 2025-05-29 con 1.50 m/s
# Tendencia: Disminución de velocidad del viento en 0.0226 m/s por día.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# Cargar datos desde CSV
df = pd.read_csv('viento_tacna_m_s.csv')

# Convertir columna 'Hora Local (America/Lima)' a datetime
df['Hora Local (America/Lima)'] = pd.to_datetime(df['Hora Local (America/Lima)'])

# Extraer la fecha (sin hora) para agrupar por día
df['Fecha'] = df['Hora Local (America/Lima)'].dt.date

# Agrupar por día y calcular velocidad media diaria del viento
daily_wind = df.groupby('Fecha')['Velocidad (m/s)'].mean()

# Encontrar día con mayor y menor velocidad media
dia_mayor_viento = daily_wind.idxmax()
mayor_velocidad = daily_wind.max()

dia_menor_viento = daily_wind.idxmin()
menor_velocidad = daily_wind.min()

print(f"Día con mayor viento promedio: {dia_mayor_viento} con {mayor_velocidad:.2f} m/s")
print(f"Día con menor viento promedio: {dia_menor_viento} con {menor_velocidad:.2f} m/s")

# Calcular tendencia lineal (regresión simple)
x = np.arange(len(daily_wind))
y = daily_wind.values

coef, intercept = np.polyfit(x, y, 1)

if coef > 0:
    print(f"Tendencia: Aumento de velocidad del viento en {coef:.4f} m/s por día.")
elif coef < 0:
    print(f"Tendencia: Disminución de velocidad del viento en {abs(coef):.4f} m/s por día.")
else:
    print("Tendencia: Velocidad del viento estable sin cambios significativos.")

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.scatter(daily_wind.index, y, color='blue', label='Velocidad media diaria (m/s)')
plt.plot(daily_wind.index, coef * x + intercept, color='red', label='Tendencia lineal')

plt.title('Velocidad media diaria del viento en Tacna')
plt.xlabel('Fecha')
plt.ylabel('Velocidad del viento (m/s)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid(True)

# Guardar la figura en archivo PNG
plt.savefig('tendencia_viento_tacna.png', dpi=300)

plt.show()
# Out:
# Día con mayor viento promedio: 2025-05-24 con 1.72 m/s
# Día con menor viento promedio: 2025-05-29 con 1.50 m/s
# Tendencia: Disminución de velocidad del viento en 0.0226 m/s por día.

# %%
import requests
from datetime import datetime
import pytz

# Coordenadas Tacna, Perú
latitude = -18.0114
longitude = -70.2463

# URL API Met.no para el pronóstico de ubicación específica
url = f"https://api.met.no/weatherapi/locationforecast/2.0/compact?lat={latitude}&lon={longitude}"

# Es importante incluir un User-Agent válido (requisito de Met.no)
headers = {
    "User-Agent": "Dante-ExampleApp/1.0 (contact: tuemail@dominio.com)"
}

response = requests.get(url, headers=headers)

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

if response.status_code == 200:
    data = response.json()

    # El pronóstico horario está en data['properties']['timeseries']
    timeseries = data['properties']['timeseries']

    # Usamos pytz para manejar zona horaria Lima
    local_tz = pytz.timezone('America/Lima')

    print(f"{'Hora Local (America/Lima)':20} | {'Velocidad (m/s)':15} | {'Dirección (°)':15} | {'Orientación'}")
    print("-"*70)

    for entry in timeseries[:24]:  # mostramos las próximas 24 horas
        time_utc = datetime.fromisoformat(entry['time'].replace('Z', '+00:00'))
        time_local = time_utc.astimezone(local_tz)

        details = entry['data']['instant']['details']

        wind_speed = details.get('wind_speed', None)
        wind_dir = details.get('wind_from_direction', None)

        if wind_speed is not None and wind_dir is not None:
            cardinal = degrees_to_cardinal(wind_dir)
            print(f"{time_local.strftime('%Y-%m-%d %H:%M'):20} | {wind_speed:<15.2f} | {wind_dir:<15.1f} | {cardinal}")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Hora Local (America/Lima) | Velocidad (m/s) | Dirección (°)   | Orientación
# ----------------------------------------------------------------------
# 2025-05-23 05:00     | 1.60            | 221.2           | SW
# 2025-05-23 06:00     | 1.50            | 318.2           | NW
# 2025-05-23 07:00     | 1.20            | 342.3           | NNW
# 2025-05-23 08:00     | 1.00            | 253.2           | WSW
# 2025-05-23 09:00     | 1.20            | 257.8           | WSW
# 2025-05-23 10:00     | 2.30            | 243.8           | WSW
# 2025-05-23 11:00     | 3.10            | 230.4           | SW
# 2025-05-23 12:00     | 3.30            | 226.5           | SW
# 2025-05-23 13:00     | 3.60            | 226.3           | SW
# 2025-05-23 14:00     | 3.80            | 224.7           | SW
# 2025-05-23 15:00     | 3.30            | 222.5           | SW
# 2025-05-23 16:00     | 2.70            | 226.7           | SW
# 2025-05-23 17:00     | 2.30            | 232.7           | SW
# 2025-05-23 18:00     | 1.70            | 211.9           | SSW
# 2025-05-23 19:00     | 1.00            | 52.3            | NE
# 2025-05-23 20:00     | 0.90            | 19.9            | NNE
# 2025-05-23 21:00     | 1.00            | 222.9           | SW
# 2025-05-23 22:00     | 0.80            | 222.9           | SW
# 2025-05-23 23:00     | 1.40            | 37.2            | NE
# 2025-05-24 00:00     | 1.70            | 45.3            | NE
# 2025-05-24 01:00     | 1.80            | 51.8            | NE
# 2025-05-24 02:00     | 1.60            | 76.8            | ENE
# 2025-05-24 03:00     | 2.00            | 65.3            | ENE
# 2025-05-24 04:00     | 1.70            | 61.7            | ENE

# %%
import requests
from datetime import datetime
import pytz
import csv

# Coordenadas Tacna, Perú
latitude = -18.0114
longitude = -70.2463

url = f"https://api.met.no/weatherapi/locationforecast/2.0/compact?lat={latitude}&lon={longitude}"

headers = {
    "User-Agent": "Renzo-Taco-WIND/1.0 (contact: rentaco@upt.pe)"
}

def degrees_to_cardinal(degrees):
    dirs = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE',
            'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
    ix = int((degrees + 11.25) / 22.5) % 16
    return dirs[ix]

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    timeseries = data['properties']['timeseries']
    local_tz = pytz.timezone('America/Lima')

    with open('viento_tacna_metno.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Escribir encabezados
        writer.writerow(['Hora Local (America/Lima)', 'Velocidad (m/s)', 'Dirección (°)', 'Orientación'])

        for entry in timeseries[:24]:  # Próximas 24 horas
            time_utc = datetime.fromisoformat(entry['time'].replace('Z', '+00:00'))
            time_local = time_utc.astimezone(local_tz)

            details = entry['data']['instant']['details']

            wind_speed = details.get('wind_speed', None)
            wind_dir = details.get('wind_from_direction', None)

            if wind_speed is not None and wind_dir is not None:
                cardinal = degrees_to_cardinal(wind_dir)
                writer.writerow([
                    time_local.strftime('%Y-%m-%d %H:%M'),
                    f"{wind_speed:.2f}",
                    f"{wind_dir:.1f}",
                    cardinal
                ])

    print("Archivo 'viento_tacna_metno.csv' creado con éxito.")
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# Archivo 'viento_tacna_metno.csv' creado con éxito.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos desde CSV generado por Met.no
df = pd.read_csv('viento_tacna_metno.csv')

# Convertir columna 'Hora Local (America/Lima)' a datetime
df['Hora Local (America/Lima)'] = pd.to_datetime(df['Hora Local (America/Lima)'])

# Extraer fecha (sin hora) para agrupar por día
df['Fecha'] = df['Hora Local (America/Lima)'].dt.date

# Agrupar por día y calcular velocidad media diaria del viento
daily_wind = df.groupby('Fecha')['Velocidad (m/s)'].mean()

# Encontrar día con mayor y menor velocidad media
dia_mayor_viento = daily_wind.idxmax()
mayor_velocidad = daily_wind.max()

dia_menor_viento = daily_wind.idxmin()
menor_velocidad = daily_wind.min()

print(f"Día con mayor viento promedio: {dia_mayor_viento} con {mayor_velocidad:.2f} m/s")
print(f"Día con menor viento promedio: {dia_menor_viento} con {menor_velocidad:.2f} m/s")

# Calcular tendencia lineal (regresión simple)
x = np.arange(len(daily_wind))
y = daily_wind.values

coef, intercept = np.polyfit(x, y, 1)

if coef > 0:
    print(f"Tendencia: Aumento de velocidad del viento en {coef:.4f} m/s por día.")
elif coef < 0:
    print(f"Tendencia: Disminución de velocidad del viento en {abs(coef):.4f} m/s por día.")
else:
    print("Tendencia: Velocidad del viento estable sin cambios significativos.")

# Graficar
plt.figure(figsize=(10, 6))
plt.scatter(daily_wind.index, y, color='blue', label='Velocidad media diaria (m/s)')
plt.plot(daily_wind.index, coef * x + intercept, color='red', label='Tendencia lineal')

plt.title('Velocidad media diaria del viento en Tacna (Met.no)')
plt.xlabel('Fecha')
plt.ylabel('Velocidad del viento (m/s)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid(True)

# Guardar gráfico
plt.savefig('tendencia_viento_tacna_metno.png', dpi=300)

plt.show()
# Out:
# Día con mayor viento promedio: 2025-05-23 con 1.98 m/s
# Día con menor viento promedio: 2025-05-24 con 1.76 m/s
# Tendencia: Disminución de velocidad del viento en 0.2242 m/s por día.
